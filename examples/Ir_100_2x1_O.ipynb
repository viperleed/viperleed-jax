# %%
import jax
from jax import config

config.update('jax_enable_x64', True)

from pathlib import Path

from matplotlib import pyplot as plt
import numpy as np


jax.devices()
# Out:
# [CpuDevice(id=0)]

# %%
# %matplotlib inline

# %%
from viperleed_jax.from_state import calculator_from_paths

from viperleed.calc.files.displacements import readDISPLACEMENTS
from viperleed.calc import LOGGER as logger
from viperleed.calc.files.phaseshifts import readPHASESHIFTS
from viperleed.calc.files.iorfactor import beamlist_to_array

# %%
origin_path = Path('../tests/test_data/Ir_100_2x1_O/start')
large_file_path = Path('../large_files/')
tensor_path = (
    large_file_path / 'Ir_100_2x1_O/start' / 'Tensors' / 'Tensors_001.zip'
)

calculator, state = calculator_from_paths(
    origin_path,
    tensor_path,
    t_leed_l_max=10,,
    recalculate_ref_t_matrices=True,
    displacements_file=origin_path / 'DISPLACEMENTS',
)
# Out:
# Starting new log: viperleed-calc-250331-120423.log
# Time of execution: 2025-03-31 12:04:23
# Starting new log: viperleed-calc-250331-120423.log
# Time of execution: 2025-03-31 12:04:23
# This is ViPErLEED version 0.13.0
#
# This is ViPErLEED version 0.13.0
#
# Reading structure from file POSCAR
# Reading structure from file POSCAR
# THEO_ENERGIES parameter: (Eto - Efrom) % Estep != 0, Efrom was corrected to 49.0
# THEO_ENERGIES parameter: (Eto - Efrom) % Estep != 0, Efrom was corrected to 49.0
# The N_CORES parameter is set to 128, which is larger than the number of available processors (10). This may not be ideal for performance, or may render execution impossible. Consider reducing N_CORES.
# # WARNING: The N_CORES parameter is set to 128, which is larger than the number of available processors (10). This may not be ideal for performance, or may render execution impossible. Consider reducing N_CORES.
# ViPErLEED is using TensErLEED version 2.0.0.
# ...
